# %%
import numpy
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_2a_i = pd.read_csv("solutions/solution_2a_i.dat", sep=r'\s+', header=None)
df_2b_i = pd.read_csv("solutions/solution_2b_i.dat", sep=r'\s+', header=None)
df_2c_i = pd.read_csv("solutions/solution_2b_i.dat", sep=r'\s+', header=None)
df_2d_i = pd.read_csv("solutions/solution_2d_i.dat", sep=r'\s+', header=None)

df_2a_ii = pd.read_csv("solutions/solution_2a_ii.dat", sep=r'\s+', header=None)
df_2b_ii = pd.read_csv("solutions/solution_2b_ii.dat", sep=r'\s+', header=None)
df_2c_ii = pd.read_csv("solutions/solution_2c_ii.dat", sep=r'\s+', header=None)
df_2d_ii = pd.read_csv("solutions/solution_2d_ii.dat", sep=r'\s+', header=None)

df_2a_iii = pd.read_csv("solutions/solution_2a_iii.dat", sep=r'\s+', header=None)
df_2b_iii = pd.read_csv("solutions/solution_2b_iii.dat", sep=r'\s+', header=None)
df_2c_iii = pd.read_csv("solutions/solution_2c_iii.dat", sep=r'\s+', header=None)
df_2d_iii = pd.read_csv("solutions/solution_2d_iii.dat", sep=r'\s+', header=None)

df_2a_iv = pd.read_csv("solutions/solution_2a_iv.dat", sep=r'\s+', header=None)
df_2b_iv = pd.read_csv("solutions/solution_2b_iv.dat", sep=r'\s+', header=None)
df_2c_iv = pd.read_csv("solutions/solution_2c_iv.dat", sep=r'\s+', header=None)
df_2d_iv = pd.read_csv("solutions/solution_2d_iv.dat", sep=r'\s+', header=None)

# %%
df_2b_iv = pd.read_csv("solutions/solution_2b_iv.dat", sep=r'\s+', header=None)

# %%
plt.plot(df_2b_iv[0], df_2b_iv[1], 'bo-') #analytical
plt.plot(df_2b_iv[0], df_2b_iv[2], 'r--') #calculated
